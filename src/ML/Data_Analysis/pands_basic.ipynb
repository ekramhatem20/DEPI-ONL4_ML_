# %%
import pandas as pd

# %%
data = [[1,444,'abc'],
        [2,555,'def'],
        [3,666,'ghi'],
        [4,777,'xyz'],
        ]
data_2 = {'ID':[1,2,3,4],
          'std_id_dict':[444,555,666,444],
          'dept':['abc','def','ghi','xyz']}

df = pd.DataFrame(data,columns=)
display(df)
# Out:
#   Cell In[2], line 10
#     df = pd.DataFrame(data,columns=)
#                            ^
# SyntaxError: expected argument value expression

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df['dept']

# %%
def duplicted(x):
    return x *2

df['std_id'].apply(lambda x : x*2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 def duplicted(x):
#       2     return x *2
# ----> 4 df['std_id'].apply(lambda x : x*2)
#
# NameError: name 'df' is not defined
