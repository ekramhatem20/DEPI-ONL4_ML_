# %%
"""
This class    
"""
class StudentInfo:
    
    def __init__(self,name = "user",age = 0):
        self.name = name
        self.age = age 
    
    def Student_info(self):
        return f"{self.name},{self.age}"

# %%
s1 = StudentInfo("Ekram")
print(s1.Student_info())
# Out:
# Ekram,0

# %%
from abc import ABC , abstractmethod

class Animal(ABC):
        
    @abstractmethod
    def move(self):
        pass    
    
class Bird(Animal):
    
    def move(self):
        print("move from Bird")
        
    
class Cat(Animal):
    
    def move(self):
        print("move from cat")

# %%
a = Bird()
a.move()
# Out:
# move from Bird
